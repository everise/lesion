# %%
import sys
sys.path.append('drive/dlstudy/script_modules')
from impl_rena import ImplReNA

impl = ImplReNA('drive/dlstudy/sample_data_deeksha/TBI_INVAX364NTZ/T1.nii.gz')
n_samples, n_x, n_y, n_z = impl.data_info()
print('number of samples: %i, \nDimensions n_x: %i, n_y: %i, n_z: %i' % (n_samples, n_x, n_y, n_z))
# Out:
# number of samples: 1,
# Dimensions n_x: 182, n_y: 218, n_z: 182

# %%
to_ward, to_rena = impl.get_connectivity()
print('Time Ward: %0.3f, Time ReNA: %0.3f' % (to_ward, to_rena))
# Out:
# Time Ward: 181.088, Time ReNA: 3.667

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
clusters_rena_fig, clusters_ward_fig, compress_rena_fig, compress_ward_fig, original_fig = impl.visualizing()
plt.show()
